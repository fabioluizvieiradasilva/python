# %% [markdown]
# # Python para Análise de Dados - Exercícios

# %% [markdown]
# 1) Importe a biblioteca Pandas

# %%
# 1-importando a biblioteca Pandas
import pandas as pd

# %% [markdown]
# 2) Leia a base de dados kc_house_data.csv localizada no diretorio datasets e crie um Dataframe chamado df.

# %%
# 2-lendo a base de dados
df = pd.read_csv('kc_house_data.csv')

# %% [markdown]
# 3) Utilizando o Dataframe criado faça:
#
# a) Conte a quantidade de linhas.
#
# b) Imprima as informações do Dataframe.
#
# c) Imprima o nome das colunas do Dataframe.
#
# d) Imprima as informações estatisticas da coluna bedrooms.
#
# e) Imprima os valores únicos da coluna bedrooms.
#
# f) Imprima o valor médio da coluna bathrooms.

# %%
# 3(a)-contando a quantidade de linhas do dataframe
df.count()
# Out:
# id               21613
# date             21613
# price            21613
# bedrooms         21609
# bathrooms        21613
# sqft_living      21613
# sqft_lot         21613
# floors           21612
# waterfront       21613
# view             21613
# condition        21613
# grade            21613
# sqft_above       21613
# sqft_basement    21613
# yr_built         21613
# yr_renovated     21613
# zipcode          21613
# lat              21613
# long             21613
# sqft_living15    21613
# sqft_lot15       21613
# dtype: int64

# %%
# 3(b)-imprimindo as informações do dataframe
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21609.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370910      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930084      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21612.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494332      0.007542      0.234303      3.409430
# ...

# %%
# 3(c)-imprimindo o nome das colunas do dataframe
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
# 3(d)- Imprima as informações estatisticas da coluna bedrooms.
df['bedrooms'].describe()
# Out:
# count    21609.000000
# mean         3.370910
# std          0.930084
# min          0.000000
# 25%          3.000000
# 50%          3.000000
# 75%          4.000000
# max         33.000000
# Name: bedrooms, dtype: float64

# %%
# 3(e) Imprima os valores únicos da coluna bedrooms.
df.bedrooms.unique()
# Out:
# array([ 3.,  2.,  4.,  5., nan,  1.,  6.,  7.,  0.,  8.,  9., 11., 10.,
#        33.])

# %%
# 3(f) Imprima o valor médio da coluna bathrooms
df.bathrooms.mean()
# Out:
# 2.1147573219821405

# %% [markdown]
# 4) Some a quantidade de valores nulos de cada coluna do Dataframe.

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# 5) Remova as linhas onde tenha pela menos um registro faltante em algum atributo.

# %%
df.dropna(inplace=True)

# %% [markdown]
# 6 Preencha com 1 os values null da coluna bedrooms.

# %%
df['bedrooms'].fillna(1, inplace=True)

# %% [markdown]
# 7 Com os seus conhecimentos em consultas faça:
#
# a) Retorne todos os imoveis que tenham o número de bathrooms maior que 1.
#
# b) Retorne todos os imoveis que tenham a quantidade de bedrooms igual a 4.
#
# c) Conte o retorno da consulta anterior.
#
# d) Ordena o Dataframe pela coluna price em ordem decrescente.
#
# e) Agrupe e conte quantidade de imóveis por tamanho de quartos

# %%
#7A
df.loc[(df['bathrooms']>1)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 1      6414100192  20141209T000000   538000.0       3.0       2.25
# 3      2487200875  20141209T000000   604000.0       4.0       3.00
# 4      1954400510  20150218T000000   510000.0       3.0       2.00
# 5      7237550310  20140512T000000  1225000.0       4.0       4.50
# 6      1321400060  20140627T000000   257500.0       3.0       2.25
# 7      2008000270  20150115T000000   291850.0       3.0       1.50
# 9      3793500160  20150312T000000   323000.0       3.0       2.50
# 10     1736800520  20150403T000000   662500.0       3.0       2.50
# 13     6054650070  20141007T000000   400000.0       3.0       1.75
# 14     1175000570  20150312T000000   530000.0       5.0       2.00
# 15     9297300055  20150124T000000   650000.0       4.0       3.00
# 16     1875500060  20140731T000000   395000.0       3.0       2.00
# 20     6300500875  20140514T000000   385000.0       4.0       1.75
# ...

# %%
# 7B
df.loc[(df['bedrooms']==4)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 3      2487200875  20141209T000000   604000.0       4.0       3.00
# 5      7237550310  20140512T000000  1225000.0       4.0       4.50
# 15     9297300055  20150124T000000   650000.0       4.0       3.00
# 17     6865200140  20140529T000000   485000.0       4.0       1.00
# 20     6300500875  20140514T000000   385000.0       4.0       1.75
# 29     1873100390  20150302T000000   719000.0       4.0       2.50
# 32      461000390  20140624T000000   687500.0       4.0       1.75
# 34     7955080270  20141203T000000   322500.0       4.0       2.75
# 36     9435300030  20140528T000000   550000.0       4.0       1.00
# 37     2768000400  20141230T000000   640000.0       4.0       2.00
# 38     7895500070  20150213T000000   240000.0       4.0       1.00
# 39     2078500320  20140620T000000   605000.0       4.0       2.50
# 40     5547700270  20140715T000000   625000.0       4.0       2.50
# ...

# %%
# 7c
df.loc[(df['bedrooms']==4)].count()
# Out:
# id               6881
# date             6881
# price            6881
# bedrooms         6881
# bathrooms        6881
# sqft_living      6881
# sqft_lot         6881
# floors           6881
# waterfront       6881
# view             6881
# condition        6881
# grade            6881
# sqft_above       6881
# sqft_basement    6881
# yr_built         6881
# yr_renovated     6881
# zipcode          6881
# lat              6881
# long             6881
# sqft_living15    6881
# sqft_lot15       6881
# dtype: int64

# %%
# 7D
df.sort_values(by='price', ascending=False)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 7252   6762700020  20141013T000000  7700000.0       6.0       8.00
# 3914   9808700762  20140611T000000  7062500.0       5.0       4.50
# 9254   9208900037  20140919T000000  6885000.0       6.0       7.75
# 4411   2470100110  20140804T000000  5570000.0       5.0       5.75
# 1448   8907500070  20150413T000000  5350000.0       5.0       5.00
# 1315   7558700030  20150413T000000  5300000.0       6.0       6.00
# 1164   1247600105  20141020T000000  5110800.0       5.0       5.25
# 8092   1924059029  20140617T000000  4668000.0       5.0       6.75
# 2626   7738500731  20140815T000000  4500000.0       5.0       5.50
# 8638   3835500195  20140618T000000  4489000.0       4.0       3.00
# 12370  6065300370  20150506T000000  4208000.0       5.0       6.00
# 4149   6447300265  20141014T000000  4000000.0       4.0       5.50
# 2085   8106100105  20141114T000000  3850000.0       4.0       4.25
# ...

# %%
#7E
pd.value_counts(df['bedrooms'])
# Out:
# 3.0     9822
# 4.0     6881
# 2.0     2758
# 5.0     1601
# 6.0      272
# 1.0      199
# 7.0       38
# 8.0       13
# 0.0       13
# 9.0        6
# 10.0       3
# 11.0       1
# 33.0       1
# Name: bedrooms, dtype: int64

# %% [markdown]
# 8) Crie uma coluna que seja a soma das colunas bathrooms e bedrooms com o nome comodos

# %%
df['comodos'] = df['bedrooms'] + df['bathrooms']

# %% [markdown]
# 9) Visualize em formato de histograma a distribuição dos imoveis por preço.

# %%
# %matplotlib notebook
df.price.hist(bins=20)
# Out:
# <img src="data:image/png;base64,..." width="855">

# %% [markdown]
# 10) Visualize em formato disperção os imoveis utilizando as colunas bathrooms e price.

# %%
df.plot(x='bathrooms', y='price', kind='scatter', title='Bathrooms x Price')
# Out:
# <img src="data:image/png;base64,..." width="811">

# %% [markdown]
# 11)Gere uma planilha do Excel a partir do Dataframe criado

# %%
df.to_excel('planilha_dados.xlsx', index=False)
